# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd "/content/gdrive/My Drive"
# Out:
# /content/gdrive/My Drive

# %% [markdown]
# Firstly import needed packages

# %%
import pandas as pd
import numpy as np
from numpy import random
import matplotlib.pyplot as plt

# %% [markdown]
# We can enerate random data for PCA by using the numpy library

# %%
Data = random.randint(200, size=(100, 10))
Data
# Out:
# array([[ 15,  11,  75,  97, 199, 137,  89,  15, 105,  26],
#        [  4, 118, 186,  22,  89, 113,  63, 122,  74,  23],
#        [ 58, 189, 149, 184,  12, 157,  34, 108, 101, 199],
#        [148,  54,  13, 194, 151, 167,  67, 121,  97,  27],
#        [128, 199, 149, 131, 195,  99,  19,  58,  74,  28],
#        [ 23, 164,  27,  36,  28,  50, 155,  36, 177, 142],
#        [  3,  44,  26,  75, 147, 180, 172, 141, 117,  12],
#        [ 23,  97, 198,   0,  51,  72, 161, 158,   8, 128],
#        [191, 101, 117, 164, 151, 119,   6,   9, 168, 194],
#        [ 47,  18,  72,  75, 192, 142, 170,  46,  71,  83],
#        [177, 146,  88, 134, 179, 157, 137,  96,  63, 117],
#        [192,  54,   0, 143,  67, 103,  33, 176,  53, 198],
#        [112,  50, 131,  63, 197,  33, 151,   0, 107,  53],
#        [ 39, 101,  35, 101,  29,  75, 115, 179,   7,  34],
#        [ 61, 190, 153, 143,  95, 180,  58, 183,  74,   3],
#        [127, 163, 128, 145,  30, 115,  60, 191,  96, 187],
# ...

# %% [markdown]
# PCA is good tool for exploratory data analysis.
# PCA works best with data sets that are three or more dimensional. This is because the higher the dimension, the more difficult it becomes to interpret in the resulting data cloud.
# PCA is applied to data sets with numeric variables. PCA is a tool that helps you create better visualizations of high-dimensional data.
#
# The number of factors for generated data is 10, so we can apply PCA to data.

# %% [markdown]
# Next, Let's perform PCA

# %%
from sklearn.preprocessing import StandardScaler
# Standardizing the features
Data = StandardScaler().fit_transform(Data)
Data
# Out:
# array([[-1.54952259e+00, -1.31738355e+00, -3.11972314e-01,
#          1.46354616e-02,  1.56591238e+00,  5.71646898e-01,
#         -1.83458849e-01, -1.49581679e+00,  1.09157870e-01,
#         -1.17823653e+00],
#        [-1.74270800e+00,  4.18577533e-01,  1.66908757e+00,
#         -1.26171294e+00, -2.42110732e-01,  1.47550281e-01,
#         -6.19068900e-01,  3.92929923e-01, -4.24579351e-01,
#         -1.23028645e+00],
#        [-7.94343271e-01,  1.57047695e+00,  1.00873428e+00,
#          1.49519960e+00, -1.50772691e+00,  9.25060745e-01,
#         -1.10494165e+00,  1.45804185e-01,  4.02885515e-02,
#          1.82330846e+00],
#        [ 7.86264608e-01, -6.19754332e-01, -1.41851027e+00,
#          1.66537939e+00,  7.76956842e-01,  1.10176767e+00,
#         -5.52051969e-01,  3.75278085e-01, -2.85807673e-02,
#         -1.16088656e+00],
#        [ 4.35018413e-01,  1.73271630e+00,  1.00873428e+00,
#          5.93246736e-01,  1.50016609e+00, -9.98394119e-02,
# ...

# %%
mean_vec = np.mean(Data, axis=0)
cov_mat = (Data - mean_vec).T.dot((Data - mean_vec)) / (Data.shape[0]-1)
print('Covariance matrix \n%s' %cov_mat)
# Out:
# Covariance matrix
# [[ 1.01010101e+00  1.63211231e-01 -1.09357463e-02  1.85959972e-01
#   -1.76137355e-02  1.40473634e-01 -3.78617956e-02 -1.44134555e-01
#    2.32988404e-03  2.55924052e-02]
#  [ 1.63211231e-01  1.01010101e+00 -2.08672524e-02  2.26844829e-01
#   -2.07746212e-02  1.56300074e-01 -1.08357173e-01  1.02259304e-01
#    1.30696170e-01  4.17729143e-02]
#  [-1.09357463e-02 -2.08672524e-02  1.01010101e+00 -1.09128971e-01
#   -2.75246343e-02 -2.54722242e-01  3.74529181e-05 -3.22523748e-03
#   -4.57253990e-02 -2.10127349e-01]
#  [ 1.85959972e-01  2.26844829e-01 -1.09128971e-01  1.01010101e+00
#    6.05511019e-02  1.61328095e-01 -5.21899252e-02  8.74543492e-02
#    1.44423699e-01 -3.87232094e-02]
#  [-1.76137355e-02 -2.07746212e-02 -2.75246343e-02  6.05511019e-02
#    1.01010101e+00  4.65461139e-03 -4.39874358e-03 -1.11004822e-01
#    2.98624893e-02 -2.10263832e-01]
#  [ 1.40473634e-01  1.56300074e-01 -2.54722242e-01  1.61328095e-01
# ...

# %% [markdown]
# Next, we perform an eigendecomposition on the covariance matrix:

# %%
cov_mat = np.cov(Data.T)
eig_vals, eig_vecs = np.linalg.eig(cov_mat)

print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvectors
# [[-0.38610186 -0.05601994 -0.14663446  0.54059132  0.13971136 -0.31934736
#   -0.12499656 -0.07379095 -0.62531303  0.02142076]
#  [-0.48175084 -0.25046644  0.11276947 -0.18435326  0.41219373  0.60269997
#    0.28921917 -0.15434799 -0.12301406 -0.05220345]
#  [ 0.3245115   0.52934416 -0.17160622 -0.17509862  0.03127001  0.0266182
#    0.42924543 -0.40535867 -0.41000476 -0.18979274]
#  [-0.51832336  0.00398406 -0.06479756 -0.54907553 -0.15480936 -0.57189671
#    0.26428355  0.00934733  0.06452004  0.0226842 ]
#  [-0.02382907  0.23578358 -0.52292804  0.10340927  0.44550629 -0.02823863
#    0.10773138  0.01571203  0.31640584  0.59029842]
#  [-0.44126004  0.55384269 -0.21253883  0.0689908  -0.14442605  0.2298202
#   -0.39730899 -0.06723276  0.25692581 -0.3828232 ]
#  [ 0.14288706 -0.01039108 -0.2186473  -0.10185214  0.47982303 -0.1303928
#    0.05046342  0.62093019 -0.05187206 -0.53223193]
#  [-0.05222685  0.0983238   0.424358    0.44159624  0.25820758 -0.28718769
# ...

# %% [markdown]
# Sorting Eigenpairs.
#
# The typical goal of a PCA is to reduce the dimensionality of the original feature space by projecting it onto a smaller subspace, where the eigenvectors will form the axes.
# In order to decide which eigenvector(s) can dropped without losing too much information for the construction of lower-dimensional subspace, we need to inspect the corresponding eigenvalues: The eigenvectors with the lowest eigenvalues bear the least information about the distribution of the data; those are the ones can be dropped.
#
# The common approach is to rank the eigenvalues from highest to lowest in order choose the top k eigenvectors.

# %%
# Make a list of (eigenvalue, eigenvector) tuples
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Sort the (eigenvalue, eigenvector) tuples from high to low
eig_pairs.sort(key=lambda x: x[0], reverse=True)

# Visually confirm that the list is correctly sorted by decreasing eigenvalues
print('Eigenvalues in descending order:')
for i in eig_pairs:
    print(i[0])
# Out:
# Eigenvalues in descending order:
# 1.6307119216878774
# 1.3468001531043534
# 1.2133300143404082
# 1.1525022785115537
# 1.0775922801844644
# 0.9662180852744319
# 0.7897051622722587
# 0.7296502396702026
# 0.6658069728164995
# 0.5286929931480567

# %%
total = sum(eig_vals)
var_exp = [(i / total)*100 for i in sorted(eig_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)

with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(6, 4))

    plt.bar(range(10), var_exp, alpha=0.5, align='center',
            label='individual explained variance')
    plt.step(range(10), cum_var_exp, where='mid',
             label='cumulative explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()
plt.show()

# %% [markdown]
# Projection Matrix.
#
# It's about time to get to the really interesting part:
# Here, we are reducing the 10-dimensional feature space to a 2-dimensional feature subspace, by choosing the "top 2" eigenvectors with the highest eigenvalues to construct our d×k-dimensional eigenvector matrix W.

# %%
matrix_w = np.hstack((eig_pairs[0][1].reshape(10,1),
                      eig_pairs[1][1].reshape(10,1)))
print('Matrix W:\n', matrix_w)
# Out:
# Matrix W:
#  [[-0.38610186 -0.14663446]
#  [-0.48175084  0.11276947]
#  [ 0.3245115  -0.17160622]
#  [-0.51832336 -0.06479756]
#  [-0.02382907 -0.52292804]
#  [-0.44126004 -0.21253883]
#  [ 0.14288706 -0.2186473 ]
#  [-0.05222685  0.424358  ]
#  [-0.15518024  0.01805808]
#  [-0.04869451  0.62072138]]

# %% [markdown]
# Projection Onto the New Feature Space(PCA rotation and dimension reduction of features).
#
# In this last step we will use the 10×2-dimensional projection matrix W to transform our samples onto the new subspace via the equation  Y=X×W, where Y is a 100×2 matrix of our transformed samples.

# %%
Y = Data.dot(matrix_w)
Y = pd.DataFrame(Y, columns = ['PC1','PC2'])
Y
# Out:
#          PC1       PC2
# 0   0.926883 -2.133150
# 1   1.624303 -0.275911
# 2  -1.530331  2.051371
# 3  -1.870736 -1.131277
# 4  -1.008280 -1.576801
# ..       ...       ...
# 95 -1.235633 -0.614541
# 96  0.305910 -0.710132
# 97 -0.953589 -0.658865
# 98  1.665231 -0.297087
# 99  0.022230 -0.508591
#
# [100 rows x 2 columns]

# %% [markdown]
# In the other hand, We can also perform PCA using Python library.

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(Data)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
principalDf
# Out:
#     principal component 1  principal component 2
# 0                0.926883              -2.133150
# 1                1.624303              -0.275911
# 2               -1.530331               2.051371
# 3               -1.870736              -1.131277
# 4               -1.008280              -1.576801
# ..                    ...                    ...
# 95              -1.235633              -0.614541
# 96               0.305910              -0.710132
# 97              -0.953589              -0.658865
# 98               1.665231              -0.297087
# 99               0.022230              -0.508591
#
# [100 rows x 2 columns]

# %%
loadings = pca.components_.T * np.sqrt(pca.explained_variance_)

loading_matrix = pd.DataFrame(loadings, columns=['PC1', 'PC2'])
loading_matrix
# Out:
#         PC1       PC2
# 0 -0.493049 -0.170172
# 1 -0.615193  0.130871
# 2  0.414399 -0.199152
# 3 -0.661895 -0.075199
# 4 -0.030430 -0.606867
# 5 -0.563486 -0.246655
# 6  0.182466 -0.253744
# 7 -0.066693  0.492475
# 8 -0.198164  0.020957
# 9 -0.062183  0.720358

# %% [markdown]
# Here each entry of the matrix contains the correlation between the original variable and the principal component.

# %% [markdown]
# As a result, We can get same results when we perform PCA using python library and don't use.

# %% [markdown]
# Visualization of PCA result

# %%
plt.figure(figsize=(6, 4))
plt.scatter(Y["PC1"],Y["PC2"])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(loc='lower center')
plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
